# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib as mpl
label_size = 14
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size

# %%
r = 1
def poblacion(x, t):
    return r * x * (1 - x)

# %%
x0 = 0.05
tt = np.linspace(0, 10)
xx = odeint(poblacion, x0, tt)

plt.plot(tt, xx)
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
def logi_sol(t, x0, r):
    return 1/(1 + (1/x0 - 1) * np.exp(-r * t))

# %%
t = np.linspace(0,10)
for r in np.arange(-1, 1,.1):
        plt.plot(t, logi_sol(t, 0.05, r))
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
r = 1
def poblacion(x, t):
    return r * x * (1 - x)

# %%
t = np.linspace(0,10)
for r in np.arange(-1, 1,.1):
    xx = odeint(poblacion, x0, tt)
    plt.plot(t, xx)

plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
#Simulacion de la derivada 2K donde P(0)=10 y k=2

# %%
k = 2
def poblacion2(P, t):
    return 2*P

# %%
x0 = 10
tt = np.linspace(0, 10)
xx = odeint(poblacion2, x0, tt)

plt.plot(tt, xx)
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
x0 = 10
tt = np.linspace(0, 10)
xx = x0*np.exp(2*tt)

plt.plot(tt, xx)
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
#Mapa Logistico

# %%
import numpy as np
def mapa_logistico(r, x):
    return r * x * (1 - x)

# %%
#r=3.99
r=3.99
n=100
x=np.zeros(n)
x[0]=0.3

for i in range (n-1):
    x[i+1] = mapa_logistico(r,x[i])
    
plt.plot(np.arange(0,n),x)
